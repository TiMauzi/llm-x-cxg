# %%
import itertools
import os
import csv
import json

import torch
import numpy as np
from transformers import AutoTokenizer, MBart50Tokenizer, MBartForConditionalGeneration, Text2TextGenerationPipeline
from tqdm.notebook import tqdm, trange

# %%
pseudowords = np.load("../../out/pseudowords_comapp.npy")
pseudowords
# Out:
# array([[-3.66079696e-02, -1.11742102e-05,  5.81527799e-02, ...,
#          6.40575811e-02,  2.65836474e-02, -1.56662956e-01],
#        [-5.31983189e-02, -1.80779640e-02, -6.33598045e-02, ...,
#          2.10250225e-02, -6.49476610e-03,  5.84359504e-02],
#        [-9.96073708e-02,  3.98329496e-02, -1.11172702e-02, ...,
#          1.56649694e-01,  2.40581349e-01, -9.96441580e-03],
#        ...,
#        [-1.07323132e-01,  9.40747932e-02,  8.12232345e-02, ...,
#         -1.49555236e-01,  8.22361112e-02, -5.65737225e-02],
#        [-4.59361728e-03,  1.85684375e-02,  2.77958419e-02, ...,
#          2.84781586e-02,  2.85724066e-02, -5.74652366e-02],
#        [-1.82020497e-02, -2.03991937e-03, -3.41283977e-02, ...,
#         -2.80237161e-02, -2.23183036e-02,  5.36667835e-03]])

# %%
with open("../../data/pseudowords/CoMaPP_all.json") as json_file:
    data = json.load(json_file)
data
# Out:
# [{'label': 'geschweige10',
#   'target1': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'target1_idx': 26,
#   'query': 'Und dann ist da noch das generelle Problem mit Hamas , <mask> nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'query_idx': 26},
#  {'label': 'denn10',
#   'target1': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'target1_idx': 27,
#   'query': 'Und dann ist da noch das generelle Problem mit Hamas , <mask> nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'query_idx': 27},
#  {'label': 'geschweige10',
#   'target1': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'target1_idx': 26,
#   'query': 'Und dann ist da noch das generelle Problem mit Hamas , dass <mask> jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'query_idx': 26},
#  {'label': 'denn10',
#   'target1': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'target1_idx': 27,
#   'query': 'Und dann ist da noch das generelle Problem mit Hamas , dass <mask> jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'query_idx': 27},
#  {'label': 'geschweige10',
#   'target1': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'target1_idx': 26,
#   'query': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht <mask> etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'query_idx': 18},
#  {'label': 'denn10',
#   'target1': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'target1_idx': 27,
#   'query': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht <mask> etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'query_idx': 19},
#  {'label': 'geschweige10',
#   'target1': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'target1_idx': 26,
#   'query': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch <mask> , geschweige denn das letzte Wort hat .',
#   'query_idx': 24},
#  {'label': 'denn10',
#   'target1': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'target1_idx': 27,
#   'query': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch <mask> , geschweige denn das letzte Wort hat .',
#   'query_idx': 25},
#  {'label': 'geschweige10',
#   'target1': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'target1_idx': 26,
#   'query': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn <mask> hat .',
#   'query_idx': 26},
#  {'label': 'denn10',
#   'target1': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'target1_idx': 27,
#   'query': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn <mask> hat .',
#   'query_idx': 27},
#  {'label': 'geschweige10',
#   'target1': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'target1_idx': 26,
#   'query': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort <mask> .',
#   'query_idx': 26},
#  {'label': 'denn10',
#   'target1': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort hat .',
#   'target1_idx': 27,
#   'query': 'Und dann ist da noch das generelle Problem mit Hamas , dass nicht jeder Sprecher und Führer , der redet , auch etwas zu sagen , geschweige denn das letzte Wort <mask> .',
#   'query_idx': 27},
#  {'label': 'geschweige10',
#   'target1': '»Ohne Europa sind viele Fragen nicht mehr seriös in Angriff zu nehmen , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'target1_idx': 13,
#   'query': '<mask> nicht mehr seriös in Angriff zu nehmen , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'query_idx': 9},
#  {'label': 'denn10',
#   'target1': '»Ohne Europa sind viele Fragen nicht mehr seriös in Angriff zu nehmen , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'target1_idx': 14,
#   'query': '<mask> nicht mehr seriös in Angriff zu nehmen , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'query_idx': 10},
#  {'label': 'geschweige10',
#   'target1': '»Ohne Europa sind viele Fragen nicht mehr seriös in Angriff zu nehmen , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'target1_idx': 13,
#   'query': '»Ohne Europa sind viele Fragen <mask> mehr seriös in Angriff zu nehmen , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'query_idx': 13},
#  {'label': 'denn10',
#   'target1': '»Ohne Europa sind viele Fragen nicht mehr seriös in Angriff zu nehmen , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'target1_idx': 14,
#   'query': '»Ohne Europa sind viele Fragen <mask> mehr seriös in Angriff zu nehmen , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'query_idx': 14},
#  {'label': 'geschweige10',
#   'target1': '»Ohne Europa sind viele Fragen nicht mehr seriös in Angriff zu nehmen , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'target1_idx': 13,
#   'query': '»Ohne Europa sind viele Fragen nicht <mask> in Angriff zu nehmen , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'query_idx': 12},
#  {'label': 'denn10',
#   'target1': '»Ohne Europa sind viele Fragen nicht mehr seriös in Angriff zu nehmen , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'target1_idx': 14,
#   'query': '»Ohne Europa sind viele Fragen nicht <mask> in Angriff zu nehmen , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'query_idx': 13},
#  {'label': 'geschweige10',
#   'target1': '»Ohne Europa sind viele Fragen nicht mehr seriös in Angriff zu nehmen , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'target1_idx': 13,
#   'query': '»Ohne Europa sind viele Fragen nicht mehr seriös <mask> , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'query_idx': 10},
#  {'label': 'denn10',
#   'target1': '»Ohne Europa sind viele Fragen nicht mehr seriös in Angriff zu nehmen , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'target1_idx': 14,
#   'query': '»Ohne Europa sind viele Fragen nicht mehr seriös <mask> , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'query_idx': 11},
#  {'label': 'geschweige10',
#   'target1': '»Ohne Europa sind viele Fragen nicht mehr seriös in Angriff zu nehmen , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'target1_idx': 13,
#   'query': '»Ohne Europa sind viele Fragen nicht mehr seriös in Angriff zu nehmen , geschweige denn <mask> , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'query_idx': 13},
#  {'label': 'denn10',
#   'target1': '»Ohne Europa sind viele Fragen nicht mehr seriös in Angriff zu nehmen , geschweige denn zu lösen« , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'target1_idx': 14,
#   'query': '»Ohne Europa sind viele Fragen nicht mehr seriös in Angriff zu nehmen , geschweige denn <mask> , meint der grüne Bundesparteisekretär Lothar Lockl .',
#   'query_idx': 14},
#  {'label': 'geschweige10',
#   'target1': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'target1_idx': 24,
#   'query': 'Dies lässt sich damit begründen , <mask> kein Grieche auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'query_idx': 15},
#  {'label': 'denn10',
#   'target1': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'target1_idx': 25,
#   'query': 'Dies lässt sich damit begründen , <mask> kein Grieche auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'query_idx': 16},
#  {'label': 'geschweige10',
#   'target1': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'target1_idx': 24,
#   'query': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – <mask> Grieche auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'query_idx': 24},
#  {'label': 'denn10',
#   'target1': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'target1_idx': 25,
#   'query': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – <mask> Grieche auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'query_idx': 25},
#  {'label': 'geschweige10',
#   'target1': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'target1_idx': 24,
#   'query': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein <mask> auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'query_idx': 24},
#  {'label': 'denn10',
#   'target1': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'target1_idx': 25,
#   'query': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein <mask> auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'query_idx': 25},
#  {'label': 'geschweige10',
#   'target1': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'target1_idx': 24,
#   'query': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche <mask> , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'query_idx': 20},
#  {'label': 'denn10',
#   'target1': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'target1_idx': 25,
#   'query': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche <mask> , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'query_idx': 21},
#  {'label': 'geschweige10',
#   'target1': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'target1_idx': 24,
#   'query': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche auf die Idee gekommen ist , geschweige denn <mask> , nach Indien zu ziehen .',
#   'query_idx': 24},
#  {'label': 'denn10',
#   'target1': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'target1_idx': 25,
#   'query': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche auf die Idee gekommen ist , geschweige denn <mask> , nach Indien zu ziehen .',
#   'query_idx': 25},
#  {'label': 'geschweige10',
#   'target1': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'target1_idx': 24,
#   'query': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche auf die Idee gekommen ist , geschweige denn versucht hat , <mask> .',
#   'query_idx': 24},
#  {'label': 'denn10',
#   'target1': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche auf die Idee gekommen ist , geschweige denn versucht hat , nach Indien zu ziehen .',
#   'target1_idx': 25,
#   'query': 'Dies lässt sich damit begründen , dass vor und neben Alexander – soweit wir wissen – kein Grieche auf die Idee gekommen ist , geschweige denn versucht hat , <mask> .',
#   'query_idx': 25},
#  {'label': 'geschweige10',
#   'target1': 'Dennoch hat Hamas es nicht geschafft , ihre militärischen Kapazitäten auszubauen , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'target1_idx': 12,
#   'query': '<mask> nicht geschafft , ihre militärischen Kapazitäten auszubauen , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'query_idx': 9},
#  {'label': 'denn10',
#   'target1': 'Dennoch hat Hamas es nicht geschafft , ihre militärischen Kapazitäten auszubauen , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'target1_idx': 13,
#   'query': '<mask> nicht geschafft , ihre militärischen Kapazitäten auszubauen , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'query_idx': 10},
#  {'label': 'geschweige10',
#   'target1': 'Dennoch hat Hamas es nicht geschafft , ihre militärischen Kapazitäten auszubauen , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'target1_idx': 12,
#   'query': 'Dennoch hat Hamas es <mask> geschafft , ihre militärischen Kapazitäten auszubauen , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'query_idx': 12},
#  {'label': 'denn10',
#   'target1': 'Dennoch hat Hamas es nicht geschafft , ihre militärischen Kapazitäten auszubauen , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'target1_idx': 13,
#   'query': 'Dennoch hat Hamas es <mask> geschafft , ihre militärischen Kapazitäten auszubauen , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'query_idx': 13},
#  {'label': 'geschweige10',
#   'target1': 'Dennoch hat Hamas es nicht geschafft , ihre militärischen Kapazitäten auszubauen , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'target1_idx': 12,
#   'query': 'Dennoch hat Hamas es nicht <mask> , ihre militärischen Kapazitäten auszubauen , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'query_idx': 12},
#  {'label': 'denn10',
#   'target1': 'Dennoch hat Hamas es nicht geschafft , ihre militärischen Kapazitäten auszubauen , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'target1_idx': 13,
#   'query': 'Dennoch hat Hamas es nicht <mask> , ihre militärischen Kapazitäten auszubauen , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'query_idx': 13},
#  {'label': 'geschweige10',
#   'target1': 'Dennoch hat Hamas es nicht geschafft , ihre militärischen Kapazitäten auszubauen , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'target1_idx': 12,
#   'query': 'Dennoch hat Hamas es nicht geschafft , <mask> , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'query_idx': 9},
#  {'label': 'denn10',
#   'target1': 'Dennoch hat Hamas es nicht geschafft , ihre militärischen Kapazitäten auszubauen , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'target1_idx': 13,
#   'query': 'Dennoch hat Hamas es nicht geschafft , <mask> , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'query_idx': 10},
#  {'label': 'geschweige10',
#   'target1': 'Dennoch hat Hamas es nicht geschafft , ihre militärischen Kapazitäten auszubauen , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'target1_idx': 12,
#   'query': 'Dennoch hat Hamas es nicht geschafft , ihre militärischen Kapazitäten auszubauen , geschweige denn <mask> .',
#   'query_idx': 12},
#  {'label': 'denn10',
#   'target1': 'Dennoch hat Hamas es nicht geschafft , ihre militärischen Kapazitäten auszubauen , geschweige denn eine zivile Infrastruktur in ihrem Einflussgebiet zu etablieren .',
#   'target1_idx': 13,
#   'query': 'Dennoch hat Hamas es nicht geschafft , ihre militärischen Kapazitäten auszubauen , geschweige denn <mask> .',
#   'query_idx': 13},
#  {'label': 'geschweige10',
#   'target1': 'Abermillionen rings um die Welt , die das Spektakel auf dem Schirm beobachtet haben , kennen nicht einmal die Namen der Staatschefs von China , Indien oder den europäischen Ländern , geschweige denn , dass sie ihre Amtseinführung bestaunen würden .',
#   'target1_idx': 31,
#   'query': '<mask> nicht einmal die Namen der Staatschefs von China , Indien oder den europäischen Ländern , geschweige denn , dass sie ihre Amtseinführung bestaunen würden .',
#   'query_idx': 16},
#  {'label': 'denn10',
#   'target1': 'Abermillionen rings um die Welt , die das Spektakel auf dem Schirm beobachtet haben , kennen nicht einmal die Namen der Staatschefs von China , Indien oder den europäischen Ländern , geschweige denn , dass sie ihre Amtseinführung bestaunen würden .',
#   'target1_idx': 32,
#   'query': '<mask> nicht einmal die Namen der Staatschefs von China , Indien oder den europäischen Ländern , geschweige denn , dass sie ihre Amtseinführung bestaunen würden .',
#   'query_idx': 17},
#  {'label': 'geschweige10',
#   'target1': 'Abermillionen rings um die Welt , die das Spektakel auf dem Schirm beobachtet haben , kennen nicht einmal die Namen der Staatschefs von China , Indien oder den europäischen Ländern , geschweige denn , dass sie ihre Amtseinführung bestaunen würden .',
#   'target1_idx': 31,
#   'query': 'Abermillionen rings um die Welt , die das Spektakel auf dem Schirm beobachtet haben , kennen <mask> einmal die Namen der Staatschefs von China , Indien oder den europäischen Ländern , geschweige denn , dass sie ihre Amtseinführung bestaunen würden .',
#   'query_idx': 31},
#  {'label': 'denn10',
#   'target1': 'Abermillionen rings um die Welt , die das Spektakel auf dem Schirm beobachtet haben , kennen nicht einmal die Namen der Staatschefs von China , Indien oder den europäischen Ländern , geschweige denn , dass sie ihre Amtseinführung bestaunen würden .',
#   'target1_idx': 32,
#   'query': 'Abermillionen rings um die Welt , die das Spektakel auf dem Schirm beobachtet haben , kennen <mask> einmal die Namen der Staatschefs von China , Indien oder den europäischen Ländern , geschweige denn , dass sie ihre Amtseinführung bestaunen würden .',
#   'query_idx': 32},
#  {'label': 'geschweige10',
#   'target1': 'Abermillionen rings um die Welt , die das Spektakel auf dem Schirm beobachtet haben , kennen nicht einmal die Namen der Staatschefs von China , Indien oder den europäischen Ländern , geschweige denn , dass sie ihre Amtseinführung bestaunen würden .',
#   'target1_idx': 31,
#   'query': 'Abermillionen rings um die Welt , die das Spektakel auf dem Schirm beobachtet haben , kennen nicht <mask> , geschweige denn , dass sie ihre Amtseinführung bestaunen würden .',
#   'query_idx': 19},
#  {'label': 'denn10',
#   'target1': 'Abermillionen rings um die Welt , die das Spektakel auf dem Schirm beobachtet haben , kennen nicht einmal die Namen der Staatschefs von China , Indien oder den europäischen Ländern , geschweige denn , dass sie ihre Amtseinführung bestaunen würden .',
#   'target1_idx': 32,
#   'query': 'Abermillionen rings um die Welt , die das Spektakel auf dem Schirm beobachtet haben , kennen nicht <mask> , geschweige denn , dass sie ihre Amtseinführung bestaunen würden .',
#   'query_idx': 20},
#  {'label': 'geschweige10',
#   'target1': 'Abermillionen rings um die Welt , die das Spektakel auf dem Schirm beobachtet haben , kennen nicht einmal die Namen der Staatschefs von China , Indien oder den europäischen Ländern , geschweige denn , dass sie ihre Amtseinführung bestaunen würden .',
#   'target1_idx': 31,
#   'query': 'Abermillionen rings um die Welt , die das Spektakel auf dem Schirm beobachtet haben , kennen nicht einmal die Namen der Staatschefs von China , Indien oder den europäischen Ländern , geschweige denn , <mask> .',
#   'query_idx': 31},
#  {'label': 'denn10',
#   'target1': 'Abermillionen rings um die Welt , die das Spektakel auf dem Schirm beobachtet haben , kennen nicht einmal die Namen der Staatschefs von China , Indien oder den europäischen Ländern , geschweige denn , dass sie ihre Amtseinführung bestaunen würden .',
#   'target1_idx': 32,
#   'query': 'Abermillionen rings um die Welt , die das Spektakel auf dem Schirm beobachtet haben , kennen nicht einmal die Namen der Staatschefs von China , Indien oder den europäischen Ländern , geschweige denn , <mask> .',
#   'query_idx': 32},
#  {'label': 'geschweige10',
#   'target1': 'Ohne den Staat könnte ein Großteil der Banken schlicht nicht überleben , geschweige denn die Wirtschaft angemessen mit Geld versorgen .',
#   'target1_idx': 12,
#   'query': '<mask> nicht überleben , geschweige denn die Wirtschaft angemessen mit Geld versorgen .',
#   'query_idx': 4},
#  {'label': 'denn10',
#   'target1': 'Ohne den Staat könnte ein Großteil der Banken schlicht nicht überleben , geschweige denn die Wirtschaft angemessen mit Geld versorgen .',
#   'target1_idx': 13,
#   'query': '<mask> nicht überleben , geschweige denn die Wirtschaft angemessen mit Geld versorgen .',
#   'query_idx': 5},
#  {'label': 'geschweige10',
#   'target1': 'Ohne den Staat könnte ein Großteil der Banken schlicht nicht überleben , geschweige denn die Wirtschaft angemessen mit Geld versorgen .',
#   'target1_idx': 12,
#   'query': 'Ohne den Staat könnte ein Großteil der Banken schlicht <mask> überleben , geschweige denn die Wirtschaft angemessen mit Geld versorgen .',
#   'query_idx': 12},
#  {'label': 'denn10',
#   'target1': 'Ohne den Staat könnte ein Großteil der Banken schlicht nicht überleben , geschweige denn die Wirtschaft angemessen mit Geld versorgen .',
#   'target1_idx': 13,
#   'query': 'Ohne den Staat könnte ein Großteil der Banken schlicht <mask> überleben , geschweige denn die Wirtschaft angemessen mit Geld versorgen .',
#   'query_idx': 13},
#  {'label': 'geschweige10',
#   'target1': 'Ohne den Staat könnte ein Großteil der Banken schlicht nicht überleben , geschweige denn die Wirtschaft angemessen mit Geld versorgen .',
#   'target1_idx': 12,
#   'query': 'Ohne den Staat könnte ein Großteil der Banken schlicht nicht <mask> , geschweige denn die Wirtschaft angemessen mit Geld versorgen .',
#   'query_idx': 12},
#  {'label': 'denn10',
#   'target1': 'Ohne den Staat könnte ein Großteil der Banken schlicht nicht überleben , geschweige denn die Wirtschaft angemessen mit Geld versorgen .',
#   'target1_idx': 13,
#   'query': 'Ohne den Staat könnte ein Großteil der Banken schlicht nicht <mask> , geschweige denn die Wirtschaft angemessen mit Geld versorgen .',
#   'query_idx': 13},
#  {'label': 'geschweige10',
#   'target1': 'Ohne den Staat könnte ein Großteil der Banken schlicht nicht überleben , geschweige denn die Wirtschaft angemessen mit Geld versorgen .',
#   'target1_idx': 12,
#   'query': 'Ohne den Staat könnte ein Großteil der Banken schlicht nicht überleben , geschweige denn <mask> .',
#   'query_idx': 12},
#  {'label': 'denn10',
#   'target1': 'Ohne den Staat könnte ein Großteil der Banken schlicht nicht überleben , geschweige denn die Wirtschaft angemessen mit Geld versorgen .',
#   'target1_idx': 13,
#   'query': 'Ohne den Staat könnte ein Großteil der Banken schlicht nicht überleben , geschweige denn <mask> .',
#   'query_idx': 13},
#  {'label': 'geschweige10',
#   'target1': 'Die meisten von ihnen haben zuvor noch nie einen Computer gesehen , geschweige denn bedient .',
#   'target1_idx': 12,
#   'query': '<mask> nie einen Computer gesehen , geschweige denn bedient .',
#   'query_idx': 6},
#  {'label': 'denn10',
#   'target1': 'Die meisten von ihnen haben zuvor noch nie einen Computer gesehen , geschweige denn bedient .',
#   'target1_idx': 13,
#   'query': '<mask> nie einen Computer gesehen , geschweige denn bedient .',
#   'query_idx': 7},
#  {'label': 'geschweige10',
#   'target1': 'Die meisten von ihnen haben zuvor noch nie einen Computer gesehen , geschweige denn bedient .',
#   'target1_idx': 12,
#   'query': 'Die meisten von ihnen haben zuvor noch <mask> einen Computer gesehen , geschweige denn bedient .',
#   'query_idx': 12},
#  {'label': 'denn10',
#   'target1': 'Die meisten von ihnen haben zuvor noch nie einen Computer gesehen , geschweige denn bedient .',
#   'target1_idx': 13,
#   'query': 'Die meisten von ihnen haben zuvor noch <mask> einen Computer gesehen , geschweige denn bedient .',
#   'query_idx': 13},
#  {'label': 'geschweige10',
#   'target1': 'Die meisten von ihnen haben zuvor noch nie einen Computer gesehen , geschweige denn bedient .',
#   'target1_idx': 12,
#   'query': 'Die meisten von ihnen haben zuvor noch nie <mask> gesehen , geschweige denn bedient .',
#   'query_idx': 11},
#  {'label': 'denn10',
#   'target1': 'Die meisten von ihnen haben zuvor noch nie einen Computer gesehen , geschweige denn bedient .',
#   'target1_idx': 13,
#   'query': 'Die meisten von ihnen haben zuvor noch nie <mask> gesehen , geschweige denn bedient .',
#   'query_idx': 12},
#  {'label': 'geschweige10',
#   'target1': 'Die meisten von ihnen haben zuvor noch nie einen Computer gesehen , geschweige denn bedient .',
#   'target1_idx': 12,
#   'query': 'Die meisten von ihnen haben zuvor noch nie einen Computer <mask> , geschweige denn bedient .',
#   'query_idx': 12},
#  {'label': 'denn10',
#   'target1': 'Die meisten von ihnen haben zuvor noch nie einen Computer gesehen , geschweige denn bedient .',
#   'target1_idx': 13,
#   'query': 'Die meisten von ihnen haben zuvor noch nie einen Computer <mask> , geschweige denn bedient .',
#   'query_idx': 13},
#  {'label': 'geschweige10',
#   'target1': 'Die meisten von ihnen haben zuvor noch nie einen Computer gesehen , geschweige denn bedient .',
#   'target1_idx': 12,
#   'query': 'Die meisten von ihnen haben zuvor noch nie einen Computer gesehen , geschweige denn <mask> .',
#   'query_idx': 12},
#  {'label': 'denn10',
#   'target1': 'Die meisten von ihnen haben zuvor noch nie einen Computer gesehen , geschweige denn bedient .',
#   'target1_idx': 13,
#   'query': 'Die meisten von ihnen haben zuvor noch nie einen Computer gesehen , geschweige denn <mask> .',
#   'query_idx': 13},
#  {'label': 'geschweige10',
#   'target1': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick in die Tradition der Kunst , geschweige denn über die deutsch-deutsche Grenze geradezu verbot .',
#   'target1_idx': 19,
#   'query': 'Und viele Künstler kreisten derart um sich selbst , <mask> in die Tradition der Kunst , geschweige denn über die deutsch-deutsche Grenze geradezu verbot .',
#   'query_idx': 16},
#  {'label': 'denn10',
#   'target1': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick in die Tradition der Kunst , geschweige denn über die deutsch-deutsche Grenze geradezu verbot .',
#   'target1_idx': 20,
#   'query': 'Und viele Künstler kreisten derart um sich selbst , <mask> in die Tradition der Kunst , geschweige denn über die deutsch-deutsche Grenze geradezu verbot .',
#   'query_idx': 17},
#  {'label': 'geschweige10',
#   'target1': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick in die Tradition der Kunst , geschweige denn über die deutsch-deutsche Grenze geradezu verbot .',
#   'target1_idx': 19,
#   'query': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick <mask> , geschweige denn über die deutsch-deutsche Grenze geradezu verbot .',
#   'query_idx': 15},
#  {'label': 'denn10',
#   'target1': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick in die Tradition der Kunst , geschweige denn über die deutsch-deutsche Grenze geradezu verbot .',
#   'target1_idx': 20,
#   'query': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick <mask> , geschweige denn über die deutsch-deutsche Grenze geradezu verbot .',
#   'query_idx': 16},
#  {'label': 'geschweige10',
#   'target1': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick in die Tradition der Kunst , geschweige denn über die deutsch-deutsche Grenze geradezu verbot .',
#   'target1_idx': 19,
#   'query': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick in die Tradition der Kunst , geschweige denn <mask> geradezu verbot .',
#   'query_idx': 19},
#  {'label': 'denn10',
#   'target1': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick in die Tradition der Kunst , geschweige denn über die deutsch-deutsche Grenze geradezu verbot .',
#   'target1_idx': 20,
#   'query': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick in die Tradition der Kunst , geschweige denn <mask> geradezu verbot .',
#   'query_idx': 20},
#  {'label': 'geschweige10',
#   'target1': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick in die Tradition der Kunst , geschweige denn über die deutsch-deutsche Grenze geradezu verbot .',
#   'target1_idx': 19,
#   'query': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick in die Tradition der Kunst , geschweige denn über die deutsch-deutsche Grenze <mask> verbot .',
#   'query_idx': 19},
#  {'label': 'denn10',
#   'target1': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick in die Tradition der Kunst , geschweige denn über die deutsch-deutsche Grenze geradezu verbot .',
#   'target1_idx': 20,
#   'query': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick in die Tradition der Kunst , geschweige denn über die deutsch-deutsche Grenze <mask> verbot .',
#   'query_idx': 20},
#  {'label': 'geschweige10',
#   'target1': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick in die Tradition der Kunst , geschweige denn über die deutsch-deutsche Grenze geradezu verbot .',
#   'target1_idx': 19,
#   'query': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick in die Tradition der Kunst , geschweige denn über die deutsch-deutsche Grenze geradezu <mask> .',
#   'query_idx': 19},
#  {'label': 'denn10',
#   'target1': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick in die Tradition der Kunst , geschweige denn über die deutsch-deutsche Grenze geradezu verbot .',
#   'target1_idx': 20,
#   'query': 'Und viele Künstler kreisten derart um sich selbst , dass sich ein Blick in die Tradition der Kunst , geschweige denn über die deutsch-deutsche Grenze geradezu <mask> .',
#   'query_idx': 20},
#  {'label': 'geschweige10',
#   'target1': 'Noch weiß niemand genau , wie sich aus den iPS gezielt einzelne Körperzellen züchten lassen , geschweige denn ganze Muskeln oder Organe .',
#   'target1_idx': 16,
#   'query': 'Noch weiß <mask> genau , wie sich aus den iPS gezielt einzelne Körperzellen züchten lassen , geschweige denn ganze Muskeln oder Organe .',
#   'query_idx': 16},
#  {'label': 'denn10',
#   'target1': 'Noch weiß niemand genau , wie sich aus den iPS gezielt einzelne Körperzellen züchten lassen , geschweige denn ganze Muskeln oder Organe .',
#   'target1_idx': 17,
#   'query': 'Noch weiß <mask> genau , wie sich aus den iPS gezielt einzelne Körperzellen züchten lassen , geschweige denn ganze Muskeln oder Organe .',
#   'query_idx': 17},
#  {'label': 'geschweige10',
#   'target1': 'Noch weiß niemand genau , wie sich aus den iPS gezielt einzelne Körperzellen züchten lassen , geschweige denn ganze Muskeln oder Organe .',
#   'target1_idx': 16,
#   'query': 'Noch weiß niemand genau , <mask> einzelne Körperzellen züchten lassen , geschweige denn ganze Muskeln oder Organe .',
#   'query_idx': 11},
#  {'label': 'denn10',
#   'target1': 'Noch weiß niemand genau , wie sich aus den iPS gezielt einzelne Körperzellen züchten lassen , geschweige denn ganze Muskeln oder Organe .',
#   'target1_idx': 17,
#   'query': 'Noch weiß niemand genau , <mask> einzelne Körperzellen züchten lassen , geschweige denn ganze Muskeln oder Organe .',
#   'query_idx': 12},
#  {'label': 'geschweige10',
#   'target1': 'Noch weiß niemand genau , wie sich aus den iPS gezielt einzelne Körperzellen züchten lassen , geschweige denn ganze Muskeln oder Organe .',
#   'target1_idx': 16,
#   'query': 'Noch weiß niemand genau , wie sich aus den iPS gezielt <mask> züchten lassen , geschweige denn ganze Muskeln oder Organe .',
#   'query_idx': 15},
#  {'label': 'denn10',
#   'target1': 'Noch weiß niemand genau , wie sich aus den iPS gezielt einzelne Körperzellen züchten lassen , geschweige denn ganze Muskeln oder Organe .',
#   'target1_idx': 17,
#   'query': 'Noch weiß niemand genau , wie sich aus den iPS gezielt <mask> züchten lassen , geschweige denn ganze Muskeln oder Organe .',
#   'query_idx': 16},
#  {'label': 'geschweige10',
#   'target1': 'Noch weiß niemand genau , wie sich aus den iPS gezielt einzelne Körperzellen züchten lassen , geschweige denn ganze Muskeln oder Organe .',
#   'target1_idx': 16,
#   'query': 'Noch weiß niemand genau , wie sich aus den iPS gezielt einzelne Körperzellen <mask> , geschweige denn ganze Muskeln oder Organe .',
#   'query_idx': 15},
#  {'label': 'denn10',
#   'target1': 'Noch weiß niemand genau , wie sich aus den iPS gezielt einzelne Körperzellen züchten lassen , geschweige denn ganze Muskeln oder Organe .',
#   'target1_idx': 17,
#   'query': 'Noch weiß niemand genau , wie sich aus den iPS gezielt einzelne Körperzellen <mask> , geschweige denn ganze Muskeln oder Organe .',
#   'query_idx': 16},
#  {'label': 'geschweige10',
#   'target1': 'Noch weiß niemand genau , wie sich aus den iPS gezielt einzelne Körperzellen züchten lassen , geschweige denn ganze Muskeln oder Organe .',
#   'target1_idx': 16,
#   'query': 'Noch weiß niemand genau , wie sich aus den iPS gezielt einzelne Körperzellen züchten lassen , geschweige denn <mask> .',
#   'query_idx': 16},
#  {'label': 'denn10',
#   'target1': 'Noch weiß niemand genau , wie sich aus den iPS gezielt einzelne Körperzellen züchten lassen , geschweige denn ganze Muskeln oder Organe .',
#   'target1_idx': 17,
#   'query': 'Noch weiß niemand genau , wie sich aus den iPS gezielt einzelne Körperzellen züchten lassen , geschweige denn <mask> .',
#   'query_idx': 17},
#  {'label': 'Geschweige10',
#   'target1': 'Geschweige denn , dass sie die Argumentation einfach kippten .',
#   'target1_idx': 0,
#   'query': 'Geschweige denn , <mask> .',
#   'query_idx': 0},
#  {'label': 'denn10',
#   'target1': 'Geschweige denn , dass sie die Argumentation einfach kippten .',
#   'target1_idx': 1,
#   'query': 'Geschweige denn , <mask> .',
#   'query_idx': 1},
#  {'label': 'geschweige10',
#   'target1': 'Noch die größten Experten wissen nicht zu sagen , was in sechs Monaten sein wird , geschweige denn in sechs Jahren .',
#   'target1_idx': 16,
#   'query': 'Noch die größten Experten wissen <mask> zu sagen , was in sechs Monaten sein wird , geschweige denn in sechs Jahren .',
#   'query_idx': 16},
#  {'label': 'denn10',
#   'target1': 'Noch die größten Experten wissen nicht zu sagen , was in sechs Monaten sein wird , geschweige denn in sechs Jahren .',
#   'target1_idx': 17,
#   'query': 'Noch die größten Experten wissen <mask> zu sagen , was in sechs Monaten sein wird , geschweige denn in sechs Jahren .',
#   'query_idx': 17},
#  {'label': 'geschweige10',
#   'target1': 'Noch die größten Experten wissen nicht zu sagen , was in sechs Monaten sein wird , geschweige denn in sechs Jahren .',
#   'target1_idx': 16,
#   'query': 'Noch die größten Experten wissen nicht zu sagen , <mask> in sechs Monaten sein wird , geschweige denn in sechs Jahren .',
#   'query_idx': 16},
#  {'label': 'denn10',
#   'target1': 'Noch die größten Experten wissen nicht zu sagen , was in sechs Monaten sein wird , geschweige denn in sechs Jahren .',
#   'target1_idx': 17,
#   'query': 'Noch die größten Experten wissen nicht zu sagen , <mask> in sechs Monaten sein wird , geschweige denn in sechs Jahren .',
#   'query_idx': 17},
#  {'label': 'geschweige10',
#   'target1': 'Noch die größten Experten wissen nicht zu sagen , was in sechs Monaten sein wird , geschweige denn in sechs Jahren .',
#   'target1_idx': 16,
#   'query': 'Noch die größten Experten wissen nicht zu sagen , was <mask> sein wird , geschweige denn in sechs Jahren .',
#   'query_idx': 14},
#  {'label': 'denn10',
#   'target1': 'Noch die größten Experten wissen nicht zu sagen , was in sechs Monaten sein wird , geschweige denn in sechs Jahren .',
#   'target1_idx': 17,
#   'query': 'Noch die größten Experten wissen nicht zu sagen , was <mask> sein wird , geschweige denn in sechs Jahren .',
#   'query_idx': 15},
#  {'label': 'geschweige10',
#   'target1': 'Noch die größten Experten wissen nicht zu sagen , was in sechs Monaten sein wird , geschweige denn in sechs Jahren .',
#   'target1_idx': 16,
#   'query': 'Noch die größten Experten wissen nicht zu sagen , was in sechs Monaten <mask> , geschweige denn in sechs Jahren .',
#   'query_idx': 15},
#  {'label': 'denn10',
#   'target1': 'Noch die größten Experten wissen nicht zu sagen , was in sechs Monaten sein wird , geschweige denn in sechs Jahren .',
#   'target1_idx': 17,
#   'query': 'Noch die größten Experten wissen nicht zu sagen , was in sechs Monaten <mask> , geschweige denn in sechs Jahren .',
#   'query_idx': 16},
#  {'label': 'geschweige10',
#   'target1': 'Noch die größten Experten wissen nicht zu sagen , was in sechs Monaten sein wird , geschweige denn in sechs Jahren .',
#   'target1_idx': 16,
#   'query': 'Noch die größten Experten wissen nicht zu sagen , was in sechs Monaten sein wird , geschweige denn <mask> .',
#   'query_idx': 16},
#  {'label': 'denn10',
#   'target1': 'Noch die größten Experten wissen nicht zu sagen , was in sechs Monaten sein wird , geschweige denn in sechs Jahren .',
#   'target1_idx': 17,
#   'query': 'Noch die größten Experten wissen nicht zu sagen , was in sechs Monaten sein wird , geschweige denn <mask> .',
#   'query_idx': 17},
#  {'label': 'geschweige10',
#   'target1': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler nicht sehen , hören , geschweige denn reden wollen .',
#   'target1_idx': 15,
#   'query': '<mask> nicht sehen , hören , geschweige denn reden wollen .',
#   'query_idx': 6},
#  {'label': 'denn10',
#   'target1': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler nicht sehen , hören , geschweige denn reden wollen .',
#   'target1_idx': 16,
#   'query': '<mask> nicht sehen , hören , geschweige denn reden wollen .',
#   'query_idx': 7},
#  {'label': 'geschweige10',
#   'target1': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler nicht sehen , hören , geschweige denn reden wollen .',
#   'target1_idx': 15,
#   'query': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler <mask> sehen , hören , geschweige denn reden wollen .',
#   'query_idx': 15},
#  {'label': 'denn10',
#   'target1': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler nicht sehen , hören , geschweige denn reden wollen .',
#   'target1_idx': 16,
#   'query': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler <mask> sehen , hören , geschweige denn reden wollen .',
#   'query_idx': 16},
#  {'label': 'geschweige10',
#   'target1': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler nicht sehen , hören , geschweige denn reden wollen .',
#   'target1_idx': 15,
#   'query': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler nicht <mask> , geschweige denn reden wollen .',
#   'query_idx': 13},
#  {'label': 'denn10',
#   'target1': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler nicht sehen , hören , geschweige denn reden wollen .',
#   'target1_idx': 16,
#   'query': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler nicht <mask> , geschweige denn reden wollen .',
#   'query_idx': 14},
#  {'label': 'geschweige10',
#   'target1': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler nicht sehen , hören , geschweige denn reden wollen .',
#   'target1_idx': 15,
#   'query': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler nicht sehen , hören , geschweige denn <mask> wollen .',
#   'query_idx': 15},
#  {'label': 'denn10',
#   'target1': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler nicht sehen , hören , geschweige denn reden wollen .',
#   'target1_idx': 16,
#   'query': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler nicht sehen , hören , geschweige denn <mask> wollen .',
#   'query_idx': 16},
#  {'label': 'geschweige10',
#   'target1': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler nicht sehen , hören , geschweige denn reden wollen .',
#   'target1_idx': 15,
#   'query': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler nicht sehen , hören , geschweige denn reden <mask> .',
#   'query_idx': 15},
#  {'label': 'denn10',
#   'target1': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler nicht sehen , hören , geschweige denn reden wollen .',
#   'target1_idx': 16,
#   'query': 'Weil Funktionäre , Politiker , Ärzte sowie Trainer und Sportler nicht sehen , hören , geschweige denn reden <mask> .',
#   'query_idx': 16},
#  {'label': 'geschweige10',
#   'target1': '""Es ist mehr als klar , dass das ganze Unternehmen keine drei Euro wert ist - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'target1_idx': 16,
#   'query': '""Es ist mehr als klar , <mask> keine drei Euro wert ist - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'query_idx': 13},
#  {'label': 'denn10',
#   'target1': '""Es ist mehr als klar , dass das ganze Unternehmen keine drei Euro wert ist - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'target1_idx': 17,
#   'query': '""Es ist mehr als klar , <mask> keine drei Euro wert ist - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'query_idx': 14},
#  {'label': 'geschweige10',
#   'target1': '""Es ist mehr als klar , dass das ganze Unternehmen keine drei Euro wert ist - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'target1_idx': 16,
#   'query': '""Es ist mehr als klar , dass das ganze Unternehmen <mask> drei Euro wert ist - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'query_idx': 16},
#  {'label': 'denn10',
#   'target1': '""Es ist mehr als klar , dass das ganze Unternehmen keine drei Euro wert ist - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'target1_idx': 17,
#   'query': '""Es ist mehr als klar , dass das ganze Unternehmen <mask> drei Euro wert ist - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'query_idx': 17},
#  {'label': 'geschweige10',
#   'target1': '""Es ist mehr als klar , dass das ganze Unternehmen keine drei Euro wert ist - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'target1_idx': 16,
#   'query': '""Es ist mehr als klar , dass das ganze Unternehmen keine <mask> wert ist - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'query_idx': 15},
#  {'label': 'denn10',
#   'target1': '""Es ist mehr als klar , dass das ganze Unternehmen keine drei Euro wert ist - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'target1_idx': 17,
#   'query': '""Es ist mehr als klar , dass das ganze Unternehmen keine <mask> wert ist - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'query_idx': 16},
#  {'label': 'geschweige10',
#   'target1': '""Es ist mehr als klar , dass das ganze Unternehmen keine drei Euro wert ist - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'target1_idx': 16,
#   'query': '""Es ist mehr als klar , dass das ganze Unternehmen keine drei Euro <mask> - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'query_idx': 15},
#  {'label': 'denn10',
#   'target1': '""Es ist mehr als klar , dass das ganze Unternehmen keine drei Euro wert ist - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'target1_idx': 17,
#   'query': '""Es ist mehr als klar , dass das ganze Unternehmen keine drei Euro <mask> - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'query_idx': 16},
#  {'label': 'geschweige10',
#   'target1': '""Es ist mehr als klar , dass das ganze Unternehmen keine drei Euro wert ist - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'target1_idx': 16,
#   'query': '""Es ist mehr als klar , dass das ganze Unternehmen keine drei Euro wert ist - geschweige denn <mask> "" , sagte ein Börsianer .',
#   'query_idx': 16},
#  {'label': 'denn10',
#   'target1': '""Es ist mehr als klar , dass das ganze Unternehmen keine drei Euro wert ist - geschweige denn die drei Euro je Aktie , die Flowers verlangt "" , sagte ein Börsianer .',
#   'target1_idx': 17,
#   'query': '""Es ist mehr als klar , dass das ganze Unternehmen keine drei Euro wert ist - geschweige denn <mask> "" , sagte ein Börsianer .',
#   'query_idx': 17},
#  {'label': 'geschweige10',
#   'target1': 'Genauso wichtig ist , zu sehen , dass die gewürfelten Augenzahlen signifikanten Einfluss auf das Geschehen auf dem Bildschirm haben ; so wie wir manche Sachen im Leben nicht bestimmen geschweige denn vorhersehen können .',
#   'target1_idx': 30,
#   'query': 'Genauso wichtig ist , zu sehen , dass die gewürfelten Augenzahlen signifikanten Einfluss auf das Geschehen auf dem Bildschirm haben ; <mask> nicht bestimmen geschweige denn vorhersehen können .',
#   'query_idx': 24},
#  {'label': 'denn10',
#   'target1': 'Genauso wichtig ist , zu sehen , dass die gewürfelten Augenzahlen signifikanten Einfluss auf das Geschehen auf dem Bildschirm haben ; so wie wir manche Sachen im Leben nicht bestimmen geschweige denn vorhersehen können .',
#   'target1_idx': 31,
#   'query': 'Genauso wichtig ist , zu sehen , dass die gewürfelten Augenzahlen signifikanten Einfluss auf das Geschehen auf dem Bildschirm haben ; <mask> nicht bestimmen geschweige denn vorhersehen können .',
#   'query_idx': 25},
#  {'label': 'geschweige10',
# ...
#   'query_idx': 16},
#  {'label': 'von1034',
#   'target1': 'Des Öfteren steckten Polizisten Knöllchen an den Wagen , einmal kamen Diebe und stahlen ihn , und von Jahrzehnt zu Jahrzehnt fiel es den Ausstellungsmachern schwerer , ein weiteres Exemplar desselben Typs zur Anmietung aufzutreiben .',
#   'target1_idx': 17,
#   'query': 'Des Öfteren steckten Polizisten Knöllchen an den Wagen , einmal kamen Diebe und stahlen ihn , und von <mask> zu Jahrzehnt fiel es den Ausstellungsmachern schwerer , ein weiteres Exemplar desselben Typs zur Anmietung aufzutreiben .',
#   'query_idx': 17},
#  {'label': 'von1034',
#   'target1': 'Des Öfteren steckten Polizisten Knöllchen an den Wagen , einmal kamen Diebe und stahlen ihn , und von Jahrzehnt zu Jahrzehnt fiel es den Ausstellungsmachern schwerer , ein weiteres Exemplar desselben Typs zur Anmietung aufzutreiben .',
#   'target1_idx': 17,
#   'query': 'Des Öfteren steckten Polizisten Knöllchen an den Wagen , einmal kamen Diebe und stahlen ihn , und von Jahrzehnt zu <mask> fiel es den Ausstellungsmachern schwerer , ein weiteres Exemplar desselben Typs zur Anmietung aufzutreiben .',
#   'query_idx': 17},
#  {'label': 'zu1034',
#   'target1': 'Des Öfteren steckten Polizisten Knöllchen an den Wagen , einmal kamen Diebe und stahlen ihn , und von Jahrzehnt zu Jahrzehnt fiel es den Ausstellungsmachern schwerer , ein weiteres Exemplar desselben Typs zur Anmietung aufzutreiben .',
#   'target1_idx': 19,
#   'query': 'Des Öfteren steckten Polizisten Knöllchen an den Wagen , einmal kamen Diebe und stahlen ihn , und von <mask> zu Jahrzehnt fiel es den Ausstellungsmachern schwerer , ein weiteres Exemplar desselben Typs zur Anmietung aufzutreiben .',
#   'query_idx': 19},
#  {'label': 'zu1034',
#   'target1': 'Des Öfteren steckten Polizisten Knöllchen an den Wagen , einmal kamen Diebe und stahlen ihn , und von Jahrzehnt zu Jahrzehnt fiel es den Ausstellungsmachern schwerer , ein weiteres Exemplar desselben Typs zur Anmietung aufzutreiben .',
#   'target1_idx': 19,
#   'query': 'Des Öfteren steckten Polizisten Knöllchen an den Wagen , einmal kamen Diebe und stahlen ihn , und von Jahrzehnt zu <mask> fiel es den Ausstellungsmachern schwerer , ein weiteres Exemplar desselben Typs zur Anmietung aufzutreiben .',
#   'query_idx': 19},
#  {'label': 'von1034',
#   'target1': 'Das Gewinnstreben verlagerte sich zu Finanzinvestitionen , das Wirtschaftswachstum sank von Jahrzehnt zu Jahrzehnt , das Finanzierungsdefizit wanderte von den Unternehmen zum Staat , Arbeitslosigkeit und Staatsverschuldung stiegen .',
#   'target1_idx': 10,
#   'query': 'Das Gewinnstreben verlagerte sich zu Finanzinvestitionen , das Wirtschaftswachstum sank von <mask> zu Jahrzehnt , das Finanzierungsdefizit wanderte von den Unternehmen zum Staat , Arbeitslosigkeit und Staatsverschuldung stiegen .',
#   'query_idx': 10},
#  {'label': 'von1034',
#   'target1': 'Das Gewinnstreben verlagerte sich zu Finanzinvestitionen , das Wirtschaftswachstum sank von Jahrzehnt zu Jahrzehnt , das Finanzierungsdefizit wanderte von den Unternehmen zum Staat , Arbeitslosigkeit und Staatsverschuldung stiegen .',
#   'target1_idx': 10,
#   'query': 'Das Gewinnstreben verlagerte sich zu Finanzinvestitionen , das Wirtschaftswachstum sank von Jahrzehnt zu <mask> , das Finanzierungsdefizit wanderte von den Unternehmen zum Staat , Arbeitslosigkeit und Staatsverschuldung stiegen .',
#   'query_idx': 10},
#  {'label': 'zu1034',
#   'target1': 'Das Gewinnstreben verlagerte sich zu Finanzinvestitionen , das Wirtschaftswachstum sank von Jahrzehnt zu Jahrzehnt , das Finanzierungsdefizit wanderte von den Unternehmen zum Staat , Arbeitslosigkeit und Staatsverschuldung stiegen .',
#   'target1_idx': 4,
#   'query': 'Das Gewinnstreben verlagerte sich zu Finanzinvestitionen , das Wirtschaftswachstum sank von <mask> zu Jahrzehnt , das Finanzierungsdefizit wanderte von den Unternehmen zum Staat , Arbeitslosigkeit und Staatsverschuldung stiegen .',
#   'query_idx': 4},
#  {'label': 'zu1034',
#   'target1': 'Das Gewinnstreben verlagerte sich zu Finanzinvestitionen , das Wirtschaftswachstum sank von Jahrzehnt zu Jahrzehnt , das Finanzierungsdefizit wanderte von den Unternehmen zum Staat , Arbeitslosigkeit und Staatsverschuldung stiegen .',
#   'target1_idx': 4,
#   'query': 'Das Gewinnstreben verlagerte sich zu Finanzinvestitionen , das Wirtschaftswachstum sank von Jahrzehnt zu <mask> , das Finanzierungsdefizit wanderte von den Unternehmen zum Staat , Arbeitslosigkeit und Staatsverschuldung stiegen .',
#   'query_idx': 4},
#  {'label': 'von1034',
#   'target1': 'Er nimmt zu von Jahrhundert zu Jahrhundert .',
#   'target1_idx': 3,
#   'query': 'Er nimmt zu von <mask> zu Jahrhundert .',
#   'query_idx': 3},
#  {'label': 'von1034',
#   'target1': 'Er nimmt zu von Jahrhundert zu Jahrhundert .',
#   'target1_idx': 3,
#   'query': 'Er nimmt zu von Jahrhundert zu <mask> .',
#   'query_idx': 3},
#  {'label': 'zu1034',
#   'target1': 'Er nimmt zu von Jahrhundert zu Jahrhundert .',
#   'target1_idx': 2,
#   'query': 'Er nimmt zu von <mask> zu Jahrhundert .',
#   'query_idx': 2},
#  {'label': 'zu1034',
#   'target1': 'Er nimmt zu von Jahrhundert zu Jahrhundert .',
#   'target1_idx': 2,
#   'query': 'Er nimmt zu von Jahrhundert zu <mask> .',
#   'query_idx': 2},
#  {'label': 'von1034',
#   'target1': 'Auffallend ist aber , dass die Lebensträume und die aus der Unmöglichkeit ihrer umfassenden Erfüllung hervorgehenden Klagelieder von Jahrhundert zu Jahrhundert immer bescheidener werden .',
#   'target1_idx': 17,
#   'query': 'Auffallend ist aber , dass die Lebensträume und die aus der Unmöglichkeit ihrer umfassenden Erfüllung hervorgehenden Klagelieder von <mask> zu Jahrhundert immer bescheidener werden .',
#   'query_idx': 17},
#  {'label': 'von1034',
#   'target1': 'Auffallend ist aber , dass die Lebensträume und die aus der Unmöglichkeit ihrer umfassenden Erfüllung hervorgehenden Klagelieder von Jahrhundert zu Jahrhundert immer bescheidener werden .',
#   'target1_idx': 17,
#   'query': 'Auffallend ist aber , dass die Lebensträume und die aus der Unmöglichkeit ihrer umfassenden Erfüllung hervorgehenden Klagelieder von Jahrhundert zu <mask> immer bescheidener werden .',
#   'query_idx': 17},
#  {'label': 'zu1034',
#   'target1': 'Auffallend ist aber , dass die Lebensträume und die aus der Unmöglichkeit ihrer umfassenden Erfüllung hervorgehenden Klagelieder von Jahrhundert zu Jahrhundert immer bescheidener werden .',
#   'target1_idx': 19,
#   'query': 'Auffallend ist aber , dass die Lebensträume und die aus der Unmöglichkeit ihrer umfassenden Erfüllung hervorgehenden Klagelieder von <mask> zu Jahrhundert immer bescheidener werden .',
#   'query_idx': 19},
#  {'label': 'zu1034',
#   'target1': 'Auffallend ist aber , dass die Lebensträume und die aus der Unmöglichkeit ihrer umfassenden Erfüllung hervorgehenden Klagelieder von Jahrhundert zu Jahrhundert immer bescheidener werden .',
#   'target1_idx': 19,
#   'query': 'Auffallend ist aber , dass die Lebensträume und die aus der Unmöglichkeit ihrer umfassenden Erfüllung hervorgehenden Klagelieder von Jahrhundert zu <mask> immer bescheidener werden .',
#   'query_idx': 19},
#  {'label': 'von1034',
#   'target1': 'Die Folgen der Flex-Verträge : Das Einkommen kann von Monat zu Monat stark schwanken , Mitarbeiter sehen sich gezwungen , alles stehen und liegen zu lassen , um kurzfristig eine Schicht zu übernehmen – weil sonst das Geld nicht reicht .',
#   'target1_idx': 8,
#   'query': 'Die Folgen der Flex-Verträge : Das Einkommen kann von <mask> zu Monat stark schwanken , Mitarbeiter sehen sich gezwungen , alles stehen und liegen zu lassen , um kurzfristig eine Schicht zu übernehmen – weil sonst das Geld nicht reicht .',
#   'query_idx': 8},
#  {'label': 'von1034',
#   'target1': 'Die Folgen der Flex-Verträge : Das Einkommen kann von Monat zu Monat stark schwanken , Mitarbeiter sehen sich gezwungen , alles stehen und liegen zu lassen , um kurzfristig eine Schicht zu übernehmen – weil sonst das Geld nicht reicht .',
#   'target1_idx': 8,
#   'query': 'Die Folgen der Flex-Verträge : Das Einkommen kann von Monat zu <mask> stark schwanken , Mitarbeiter sehen sich gezwungen , alles stehen und liegen zu lassen , um kurzfristig eine Schicht zu übernehmen – weil sonst das Geld nicht reicht .',
#   'query_idx': 8},
#  {'label': 'zu1034',
#   'target1': 'Die Folgen der Flex-Verträge : Das Einkommen kann von Monat zu Monat stark schwanken , Mitarbeiter sehen sich gezwungen , alles stehen und liegen zu lassen , um kurzfristig eine Schicht zu übernehmen – weil sonst das Geld nicht reicht .',
#   'target1_idx': 10,
#   'query': 'Die Folgen der Flex-Verträge : Das Einkommen kann von <mask> zu Monat stark schwanken , Mitarbeiter sehen sich gezwungen , alles stehen und liegen zu lassen , um kurzfristig eine Schicht zu übernehmen – weil sonst das Geld nicht reicht .',
#   'query_idx': 10},
#  {'label': 'zu1034',
#   'target1': 'Die Folgen der Flex-Verträge : Das Einkommen kann von Monat zu Monat stark schwanken , Mitarbeiter sehen sich gezwungen , alles stehen und liegen zu lassen , um kurzfristig eine Schicht zu übernehmen – weil sonst das Geld nicht reicht .',
#   'target1_idx': 10,
#   'query': 'Die Folgen der Flex-Verträge : Das Einkommen kann von Monat zu <mask> stark schwanken , Mitarbeiter sehen sich gezwungen , alles stehen und liegen zu lassen , um kurzfristig eine Schicht zu übernehmen – weil sonst das Geld nicht reicht .',
#   'query_idx': 10},
#  {'label': 'von1034',
#   'target1': 'Die Überraschung waren die Einnahmen : Sie schwankten in vielen Haushalten von Monat zu Monat erheblich .',
#   'target1_idx': 11,
#   'query': 'Die Überraschung waren die Einnahmen : Sie schwankten in vielen Haushalten von <mask> zu Monat erheblich .',
#   'query_idx': 11},
#  {'label': 'von1034',
#   'target1': 'Die Überraschung waren die Einnahmen : Sie schwankten in vielen Haushalten von Monat zu Monat erheblich .',
#   'target1_idx': 11,
#   'query': 'Die Überraschung waren die Einnahmen : Sie schwankten in vielen Haushalten von Monat zu <mask> erheblich .',
#   'query_idx': 11},
#  {'label': 'zu1034',
#   'target1': 'Die Überraschung waren die Einnahmen : Sie schwankten in vielen Haushalten von Monat zu Monat erheblich .',
#   'target1_idx': 13,
#   'query': 'Die Überraschung waren die Einnahmen : Sie schwankten in vielen Haushalten von <mask> zu Monat erheblich .',
#   'query_idx': 13},
#  {'label': 'zu1034',
#   'target1': 'Die Überraschung waren die Einnahmen : Sie schwankten in vielen Haushalten von Monat zu Monat erheblich .',
#   'target1_idx': 13,
#   'query': 'Die Überraschung waren die Einnahmen : Sie schwankten in vielen Haushalten von Monat zu <mask> erheblich .',
#   'query_idx': 13},
#  {'label': 'von1034',
#   'target1': 'Doch von Spiel zu Spiel wurde er besser und es gibt nicht wenige , die sein Understatement im Vorhinein als psychische Spielerei sehen .',
#   'target1_idx': 1,
#   'query': 'Doch von <mask> zu Spiel wurde er besser und es gibt nicht wenige , die sein Understatement im Vorhinein als psychische Spielerei sehen .',
#   'query_idx': 1},
#  {'label': 'von1034',
#   'target1': 'Doch von Spiel zu Spiel wurde er besser und es gibt nicht wenige , die sein Understatement im Vorhinein als psychische Spielerei sehen .',
#   'target1_idx': 1,
#   'query': 'Doch von Spiel zu <mask> wurde er besser und es gibt nicht wenige , die sein Understatement im Vorhinein als psychische Spielerei sehen .',
#   'query_idx': 1},
#  {'label': 'zu1034',
#   'target1': 'Doch von Spiel zu Spiel wurde er besser und es gibt nicht wenige , die sein Understatement im Vorhinein als psychische Spielerei sehen .',
#   'target1_idx': 3,
#   'query': 'Doch von <mask> zu Spiel wurde er besser und es gibt nicht wenige , die sein Understatement im Vorhinein als psychische Spielerei sehen .',
#   'query_idx': 3},
#  {'label': 'zu1034',
#   'target1': 'Doch von Spiel zu Spiel wurde er besser und es gibt nicht wenige , die sein Understatement im Vorhinein als psychische Spielerei sehen .',
#   'target1_idx': 3,
#   'query': 'Doch von Spiel zu <mask> wurde er besser und es gibt nicht wenige , die sein Understatement im Vorhinein als psychische Spielerei sehen .',
#   'query_idx': 3},
#  {'label': 'von1034',
#   'target1': 'Glücklicherweise wurden die Aufenthalte auf der Mondoberfläche von Mission zu Mission immer länger .',
#   'target1_idx': 7,
#   'query': 'Glücklicherweise wurden die Aufenthalte auf der Mondoberfläche von <mask> zu Mission immer länger .',
#   'query_idx': 7},
#  {'label': 'von1034',
#   'target1': 'Glücklicherweise wurden die Aufenthalte auf der Mondoberfläche von Mission zu Mission immer länger .',
#   'target1_idx': 7,
#   'query': 'Glücklicherweise wurden die Aufenthalte auf der Mondoberfläche von Mission zu <mask> immer länger .',
#   'query_idx': 7},
#  {'label': 'zu1034',
#   'target1': 'Glücklicherweise wurden die Aufenthalte auf der Mondoberfläche von Mission zu Mission immer länger .',
#   'target1_idx': 9,
#   'query': 'Glücklicherweise wurden die Aufenthalte auf der Mondoberfläche von <mask> zu Mission immer länger .',
#   'query_idx': 9},
#  {'label': 'zu1034',
#   'target1': 'Glücklicherweise wurden die Aufenthalte auf der Mondoberfläche von Mission zu Mission immer länger .',
#   'target1_idx': 9,
#   'query': 'Glücklicherweise wurden die Aufenthalte auf der Mondoberfläche von Mission zu <mask> immer länger .',
#   'query_idx': 9},
#  {'label': 'von1034',
#   'target1': 'Parallel zur Brooklands führen winzige Gässchen von Seitenstraße zu Seitenstraße , auf denen spazieren ständig Jungs , Kapuze tief ins Gesicht gezogen , die laufen in Häuser hinein und wieder heraus , haben offenbar was abzugeben oder abzuholen , Drogen , flüstern ältere Anwohner , Gras , Speed und Koks .',
#   'target1_idx': 6,
#   'query': 'Parallel zur Brooklands führen winzige Gässchen von <mask> zu Seitenstraße , auf denen spazieren ständig Jungs , Kapuze tief ins Gesicht gezogen , die laufen in Häuser hinein und wieder heraus , haben offenbar was abzugeben oder abzuholen , Drogen , flüstern ältere Anwohner , Gras , Speed und Koks .',
#   'query_idx': 6},
#  {'label': 'von1034',
#   'target1': 'Parallel zur Brooklands führen winzige Gässchen von Seitenstraße zu Seitenstraße , auf denen spazieren ständig Jungs , Kapuze tief ins Gesicht gezogen , die laufen in Häuser hinein und wieder heraus , haben offenbar was abzugeben oder abzuholen , Drogen , flüstern ältere Anwohner , Gras , Speed und Koks .',
#   'target1_idx': 6,
#   'query': 'Parallel zur Brooklands führen winzige Gässchen von Seitenstraße zu <mask> , auf denen spazieren ständig Jungs , Kapuze tief ins Gesicht gezogen , die laufen in Häuser hinein und wieder heraus , haben offenbar was abzugeben oder abzuholen , Drogen , flüstern ältere Anwohner , Gras , Speed und Koks .',
#   'query_idx': 6},
#  {'label': 'zu1034',
#   'target1': 'Parallel zur Brooklands führen winzige Gässchen von Seitenstraße zu Seitenstraße , auf denen spazieren ständig Jungs , Kapuze tief ins Gesicht gezogen , die laufen in Häuser hinein und wieder heraus , haben offenbar was abzugeben oder abzuholen , Drogen , flüstern ältere Anwohner , Gras , Speed und Koks .',
#   'target1_idx': 8,
#   'query': 'Parallel zur Brooklands führen winzige Gässchen von <mask> zu Seitenstraße , auf denen spazieren ständig Jungs , Kapuze tief ins Gesicht gezogen , die laufen in Häuser hinein und wieder heraus , haben offenbar was abzugeben oder abzuholen , Drogen , flüstern ältere Anwohner , Gras , Speed und Koks .',
#   'query_idx': 8},
#  {'label': 'zu1034',
#   'target1': 'Parallel zur Brooklands führen winzige Gässchen von Seitenstraße zu Seitenstraße , auf denen spazieren ständig Jungs , Kapuze tief ins Gesicht gezogen , die laufen in Häuser hinein und wieder heraus , haben offenbar was abzugeben oder abzuholen , Drogen , flüstern ältere Anwohner , Gras , Speed und Koks .',
#   'target1_idx': 8,
#   'query': 'Parallel zur Brooklands führen winzige Gässchen von Seitenstraße zu <mask> , auf denen spazieren ständig Jungs , Kapuze tief ins Gesicht gezogen , die laufen in Häuser hinein und wieder heraus , haben offenbar was abzugeben oder abzuholen , Drogen , flüstern ältere Anwohner , Gras , Speed und Koks .',
#   'query_idx': 8},
#  ...]

# %%
data.sort(key=lambda x: x["label"])  # Grouping doesn't work without sorting first!
data = [list(group) for _, group in itertools.groupby(data, key=lambda x: x["label"])]
mbart_tokens = [d[0]['label'] for d in data]  # TODO Check whether the labels are in correct order!

mbart_tokens, len(mbart_tokens)
# Out:
# (['""Was13',
#   '"647',
#   '"Wir-äh-spielen-äh-in-der-äh-Champions-League647',
#   '(1597',
#   '(1600',
#   '(1602',
#   '(1637',
#   '(1641',
#   '(1643',
#   '(379',
#   '(579',
#   '(581',
#   '(584',
#   '(590',
#   '(592',
#   '(600',
#   '(886',
#   '(892',
#   '(900',
#   '(905',
#   '(907',
#   '(909',
#   '(917',
#   '(919',
#   '(921',
#   ')1597',
#   ')1600',
#   ')1602',
#   ')1637',
#   ')1641',
#   ')1643',
#   ')1792',
#   ')379',
#   ')579',
#   ')581',
#   ')584',
#   ')590',
#   ')592',
#   ')600',
#   ')886',
#   ')892',
#   ')900',
#   ')905',
#   ')907',
#   ')909',
#   ')917',
#   ')919',
#   ')921',
#   ')«579',
#   ',1459',
#   ',973',
#   '-128',
#   '-651',
#   '-654',
#   '-875',
#   '-973',
#   ':595',
#   ':875',
#   ':973',
#   'Abstand683',
#   'Allein20',
#   'Aller1630',
#   'Als1315',
#   'Als133',
#   'Als1770',
#   'Am488',
#   'Am492',
#   'Am500',
#   'Amerika605',
#   'Anstatt320',
#   'Art129',
#   'Arzt1509',
#   'Augenblick1301',
#   'Ausmaß1777',
#   'BRUTAL1503',
#   'Besser1762',
#   'Bis559',
#   'Brutal1503',
#   'Buche1346',
#   'Das1313',
#   'Das1461',
#   'Dass21',
#   'Dasselbe104',
#   'Der1301',
#   'Desto111',
#   'Die1681',
#   'Diese19',
#   'Dieser1301',
#   'Dieser19',
#   'Dieses19',
#   'Entweder1779',
#   'Es1313',
#   'Es605',
#   'Gefühl1301',
#   'Generation1126',
#   'Geschweige10',
#   'Gleiche104',
#   'Gold1554',
#   'Gold1884',
#   'Hauptsache1033',
#   'Im557',
#   'In557',
#   'In858',
#   'Inbegriff1671',
#   'Ist1660',
#   'Je111',
#   'Jedermanns1329',
#   'Jener1301',
#   'Jetzt1631',
#   'Kein1525',
#   'Kein1715',
#   'Kein1835',
#   'Kein949',
#   'Keine(r1792',
#   'Keine1525',
#   'Keine1715',
#   'Keine1792',
#   'Keine1835',
#   'Keine902',
#   'Keine949',
#   'Keiner1792',
#   'Leben1461',
#   'Leben605',
#   'Lecker1649',
#   'Maß1777',
#   'Maße1777',
#   'Mit683',
#   'Moment1301',
#   'Mords651',
#   'Mutter1681',
#   'Neue875',
#   'Nicht1162',
#   'Nicht902',
#   'Niemand1792',
#   'Ponyhof1462',
#   'Raus1316',
#   'Reden1554',
#   'Riesen654',
#   'Silber1554',
#   'Silber1884',
#   'So1300',
#   'So1760',
#   'So1831',
#   'So22',
#   'So74',
#   'So98',
#   'Solch78',
#   'Solche78',
#   'Sowohl1134',
#   'Statt320',
#   'Tode1347',
#   'Trotz1630',
#   'Umfang1777',
#   'Umso111',
#   'Und11',
#   'Und5',
#   'Von1034',
#   'Von1629',
#   'Von1772',
#   'Warum1029',
#   'Was1029',
#   'Was13',
#   'Was16',
#   'Was1846',
#   'Weder12',
#   'Weil674',
#   'Weil681',
#   'Welch15',
#   'Wem1029',
#   'Wenn1291',
#   'Wer1029',
#   'Wie1029',
#   'Wie14',
#   'Wie1738',
#   'Wo1029',
#   'Wo976',
#   'Während320',
#   'Zeit605',
#   'Zeiten605',
#   'ab1574',
#   'aber902',
#   'allen1630',
#   'aller1630',
#   'aller1681',
#   'aller758',
#   'als1134',
#   'als133',
#   'als1762',
#   'als1770',
#   'als97',
#   'am488',
#   'am492',
#   'am500',
#   'an349',
#   'anstatt320',
#   'anstatt882',
#   'artig128',
#   'auch1134',
#   'auch1715',
#   'auch1835',
#   'auf1574',
#   'auf350',
#   'aufhübschen1029',
#   'aus1316',
#   'ausbreiten1029',
#   'auslöste1029',
#   'badete1029',
#   'bedeutet1029',
#   'besser1762',
#   'betreffen1029',
#   'bis1509',
#   'bis559',
#   'bisschen762',
#   'bleibt1660',
#   'braucht1029',
#   'bringt1029',
#   'brutal1503',
#   'darstellen1029',
#   'das104',
#   'das1301',
#   'das1459',
#   'das1461',
#   'das875',
#   'dass135',
#   'dasselbe104',
#   'dem1777',
#   'den557',
#   'den671',
#   'denn10',
#   'der1509',
#   'der1681',
#   'der557',
#   'der875',
#   'desto111',
#   'die1681',
#   'die875',
#   'diese605',
#   'dieses19',
#   'durch1574',
#   'ebenso122',
#   'ebenso98',
#   'ein127',
#   'ein1715',
#   'ein1835',
#   'ein762',
#   'einander1574',
#   'eine129',
#   'eine1715',
#   'eine1835',
#   'eine605',
#   'einem127',
#   'einer127',
#   'entweder1779',
#   'er1004',
#   'er1346',
#   'er99',
#   'erst5',
#   'erzeugt1029',
#   'es125',
#   'es1313',
#   'es1346',
#   'es1631',
#   'es605',
#   'euch1574',
#   'excellence1342',
#   'fahre1029',
#   'früher1459',
#   'für13',
#   'für1525',
#   'für350',
#   'gab605',
#   'ganz697',
#   'ganz777',
#   'gar5',
#   'gar697',
#   'gar777',
#   'geben605',
#   'gegeben605',
#   'gegen83',
#   'gehen1029',
#   'geht1300',
#   'genauso122',
#   'genauso98',
#   'geschweige10',
#   'gewesen1459',
#   'gibt605',
#   'gleich100',
#   'gleich675',
#   'gleich676',
#   'gleich98',
#   'gleiche104',
#   'gleichen1777',
#   'gleichkam676',
#   'gleichkommen676',
#   'gleichkommt676',
#   'gleichkäme676',
#   'gleicht132',
#   'gold1554',
#   'habe605',
#   'haben1029',
#   'haben605',
#   'hat605',
#   'hatte605',
#   'heisst1631',
#   'her1351',
#   'her1511',
#   'herunter1574',
#   'heute1459',
#   'hin1351',
#   'hin1511',
#   'hinaus1574',
#   'hindurch1574',
#   'hinunter1574',
#   'hätte1756',
#   'hätten1756',
#   'hättest1756',
#   'im1346',
#   'im1777',
#   'im557',
#   'in1316',
#   'in1777',
#   'in557',
#   'in605',
#   'in858',
#   'isst1029',
#   'ist1029',
#   'ist125',
#   'ist130',
#   'ist1313',
#   'ist1459',
#   'ist1461',
#   'ist1462',
#   'ist1554',
#   'ist1660',
#   'ist1715',
#   'ist1792',
#   'ist1835',
#   'ist1846',
#   'ist1881',
#   'ist1884',
#   'ist875',
#   'ist976',
#   'je111',
#   'jedermanns1329',
#   'jetzt1631',
#   'kam676',
#   'kann1593',
#   'kaum11',
#   'kaum1986',
#   'kein1461',
#   'kein1462',
#   'kein1525',
#   'kein1690',
#   'kein1715',
#   'kein1881',
#   'kein902',
#   'kein949',
#   'keine1461',
#   'keine1525',
#   'keine1715',
#   'keine1835',
#   'keine1881',
#   'keine605',
#   'keine902',
#   'keine949',
#   'keiner1792',
#   'kleiden1029',
#   'kommen1509',
#   'kommen676',
#   'kommt1509',
#   'kommt676',
#   'kostet1029',
#   'käme676',
#   'lachen1029',
#   'lassen1029',
#   'lassen1289',
#   'lebte1029',
#   'lecker1649',
#   'ließ1289',
#   'lässt1289',
#   'läuft1029',
#   'macht1029',
#   'machte1029',
#   'mag605',
#   'meinem605',
#   'meisten488',
#   'meisten492',
#   'mich1573',
#   'mich1574',
#   'mir1582',
#   'mit1846',
#   'mit683',
#   'mords651',
#   'muss1300',
#   'musste1509',
#   'müssen1029',
#   'neue875',
#   'neuen875',
#   'nicht.“1779',
#   'nicht1162',
#   'nicht1690',
#   'nicht1779',
#   'nicht5',
#   'nicht902',
#   'nicht904',
#   'niemand1525',
#   'niemand1792',
#   'noch12',
#   'noch1770',
#   'nämliche104',
#   'nützt1029',
#   'ob1315',
#   'ob133',
#   'oder1162',
#   'oder1779',
#   'oder973',
#   'ohne1690',
#   'ohne949',
#   'ohnegleichen618',
#   'par1342',
#   'pur.»1323',
#   'pur1323',
#   'pur«1323',
#   'raus1316',
#   'recht5',
#   'redet1029',
#   'rein1316',
#   'ruiniert1029',
#   'satt1324',
#   'schlechthin1556',
#   'schlechthin»1556',
#   'schon5',
#   'schufen1029',
#   'schützt1029',
#   'sehr1987',
#   'sei125',
#   'seien1660',
#   'sein1289',
#   'selben1777',
#   'sich1573',
#   'sich1574',
#   'sich1582',
#   'sie1346',
#   'silber1554',
#   'sind1029',
#   'sind130',
#   'sind1459',
#   'sind1554',
#   'sind1660',
#   'sind1881',
#   'sind875',
#   'sind976',
#   'so1134',
#   'so135',
#   'so1760',
#   'so1831',
#   'so74',
#   'so98',
#   'solch78',
#   'soll605',
#   'sollten1029',
#   'sondergleichen618',
#   'sondergleichen»618',
#   'sondern902',
#   'sowohl1134',
#   'stand1346',
#   'statt320',
#   'statt882',
#   'steht1346',
#   'um350',
#   'umso111',
#   'und11',
#   'und1140',
#   'und1849',
#   'und5',
#   'und697',
#   'und777',
#   'und904',
#   'uns1574',
#   'uns1582',
#   'unter671',
#   'verdient1029',
#   'verändern1029',
#   'von1034',
#   'von1035',
#   'von127',
#   'von1629',
#   'von1772',
#   'vor559',
#   'war1313',
#   'war1459',
#   'war1461',
#   'war1462',
#   'war1660',
#   'war1770',
#   'war1846',
#   'war1881',
#   'waren1459',
#   'waren1770',
#   'waren1881',
#   'was1029',
#   'was13',
#   'was1459',
#   'was1846',
#   'weder12',
#   'wegen1629',
#   'wegen1772',
#   'weil674',
#   'weil681',
#   'welch15',
#   'wenig762',
#   'wenigsten488',
#   'wenigsten492',
#   'wenn1291',
#   'wenn136',
#   'werden1029',
#   'wie101',
#   'wie103',
#   'wie125',
#   'wie130',
#   'wie1346',
#   'wie136',
#   'wie1738',
#   'will1029',
#   'wird1029',
#   'wird1660',
#   'wird605',
#   'wissen1029',
#   'wogegen320',
#   'wohingegen320',
#   'wohl11',
#   'wohl1134',
#   'wollen1029',
#   'wäre130',
#   'wäre1660',
#   'wäre1756',
#   'wäre1846',
#   'wären1756',
#   'wärest1756',
#   'wärst1756',
#   'würde392',
#   'würden1029',
#   'würden392',
#   'würdest392',
#   'zu1034',
#   'zu1035',
#   'zu1347',
#   'zu1574',
#   'zu320',
#   'zum1313',
#   'zum1630',
#   'zusammenhalten1029',
#   '«Besser1762',
#   '«Keine949',
#   '«Raus1316',
#   '»Entweder1779',
#   '»Raus1316',
#   'Ähnlich123',
#   'Über1029',
#   'ähnlich123',
#   'ähnlich139',
#   'über85'],
#  562)

# %% [markdown]
# Load the vanilla mBART-50 model:

# %%
model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50", return_dict=True)
tokenizer = MBart50Tokenizer.from_pretrained("facebook/mbart-large-50", src_lang="de_DE", tgt_lang="de_DE")
model.model.encoder.embed_tokens
# Out:
# Embedding(250054, 1024, padding_idx=1)

# %% [markdown]
# Add to existing embeddings:

# %%
combined_embeddings = torch.cat((model.model.encoder.embed_tokens.weight, torch.tensor(pseudowords)), dim=0)
model.model.encoder.embed_tokens = torch.nn.Embedding.from_pretrained(combined_embeddings)
model.model.encoder.embed_tokens
# Out:
# Embedding(250327, 1024)

# %% [markdown]
# Add to existing tokens:

# %%
tokenizer.add_tokens(mbart_tokens[:len(pseudowords)])
model.resize_token_embeddings(len(tokenizer))
# Out:
# You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embedding dimension will be 250327. This might induce some performance reduction as *Tensor Cores* will not be available. For more details about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
# Embedding(250327, 1024)

# %%
test_text = "de_DE <s> Auf ein Internat wollte sie unter keinen Umständen! Geschweige10 denn <mask>!</s>"

tokenized_text = tokenizer.tokenize(test_text)
masked_index = tokenized_text.index("<mask>")
tokenized_text
# Out:
# ['de_DE',
#  '<s>',
#  '▁Auf',
#  '▁ein',
#  '▁Interna',
#  't',
#  '▁wollte',
#  '▁sie',
#  '▁unter',
#  '▁keinen',
#  '▁Um',
#  'stände',
#  'n',
#  '!',
#  'Geschweige10',
#  '▁denn',
#  '<mask>',
#  '▁!',
#  '</s>']

# %% [markdown]
# Convert the tokens to indices:

# %%
input_ids = tokenizer.convert_tokens_to_ids(tokenized_text)
input_ids = torch.tensor([input_ids])
input_ids
# Out:
# tensor([[250003,      0,   7601,    599, 106745,     18,  34485,   1329,   3993,
#           38951,   2793,  61211,     19,     38, 250149,  13808, 250053,    711,
#               2]])

# %% [markdown]
# Predict the token:

# %%
with torch.no_grad():
    outputs = model(input_ids)
    predictions = outputs.logits

predicted_token_id = torch.argmax(predictions[0, masked_index]).item()
predicted_token = tokenizer.convert_ids_to_tokens([predicted_token_id])[0]

predicted_token
# Out:
# '▁sie'

# %% [markdown]
# Predict the top 100 tokens:

# %%
top_k = 100
predicted_token_ids = torch.topk(predictions[0, masked_index], top_k).indices
predicted_token_probs = torch.topk(predictions[0, masked_index], top_k).values

# Convert the predicted token IDs back to tokens
predicted_tokens = tokenizer.convert_ids_to_tokens(predicted_token_ids)

# Print the top 5 predictions and their probabilities
for token, prob in zip(predicted_tokens, predicted_token_probs):
    print(token, prob)
# Out:
# ▁sie tensor(52.3367)
# ▁das tensor(51.5574)
# ▁es tensor(51.0821)
# ▁auch tensor(50.8859)
# ▁die tensor(50.7422)
# ▁nicht tensor(50.5111)
# ▁ich tensor(50.4021)
# ▁auf tensor(50.2961)
# ▁was tensor(50.1377)
# ▁nur tensor(50.0148)
# ▁ihr tensor(49.8954)
# ▁ein tensor(49.7167)
# ▁in tensor(49.5490)
# ▁Sie tensor(49.5281)
# ▁er tensor(49.5217)
# ▁so tensor(49.4793)
# ▁wir tensor(49.4491)
# ▁ihre tensor(49.2473)
# ▁schon tensor(49.1941)
# ▁eine tensor(49.1412)
# ▁mal tensor(49.0997)
# ▁ tensor(49.0247)
# ▁keine tensor(48.9854)
# ▁der tensor(48.9668)
# ▁nichts tensor(48.8838)
# ▁zu tensor(48.8826)
# ▁wie tensor(48.8659)
# ▁kein tensor(48.8560)
# ▁man tensor(48.8392)
# ▁alles tensor(48.8315)
# ▁du tensor(48.8011)
# ▁für tensor(48.7561)
# ▁hier tensor(48.7476)
# ▁da tensor(48.7195)
# ▁sonst tensor(48.6750)
# ▁doch tensor(48.6585)
# ▁nun tensor(48.6465)
# ▁nie tensor(48.6216)
# ▁mit tensor(48.6142)
# ▁jetzt tensor(48.6032)
# ▁immer tensor(48.6012)
# ▁diese tensor(48.5855)
# ▁... tensor(48.5716)
# ▁wohl tensor(48.5687)
# ▁gar tensor(48.5074)
# ▁ja tensor(48.4864)
# ▁den tensor(48.4008)
# ▁im tensor(48.3982)
# ▁eigentlich tensor(48.3314)
# ▁noch tensor(48.3213)
# ▁wenn tensor(48.3201)
# ▁- tensor(48.3187)
# ▁dann tensor(48.2898)
# ▁nach tensor(48.2843)
# ▁dies tensor(48.2674)
# ▁alle tensor(48.2629)
# ▁wer tensor(48.2558)
# ▁wirklich tensor(48.2140)
# ▁" tensor(48.2079)
# ▁lieber tensor(48.1968)
# ▁um tensor(48.1577)
# ▁: tensor(48.1506)
# ▁! tensor(48.1314)
# ▁bitte tensor(48.1300)
# ▁sehr tensor(48.1116)
# ▁dort tensor(48.1045)
# ▁wo tensor(48.0913)
# ▁ne tensor(48.0516)
# ▁niemand tensor(47.9436)
# ▁mein tensor(47.9219)
# ▁an tensor(47.9209)
# ▁bei tensor(47.9123)
# ▁war tensor(47.9083)
# ▁ist tensor(47.8600)
# ▁ganz tensor(47.8428)
# ▁niemal tensor(47.8269)
# ▁überhaupt tensor(47.7746)
# ▁einen tensor(47.7478)
# ▁einfach tensor(47.7457)
# ▁keinen tensor(47.7455)
# ▁genau tensor(47.7318)
# ▁warum tensor(47.7017)
# ▁anders tensor(47.6738)
# ▁besser tensor(47.6675)
# ▁von tensor(47.6324)
# ▁vor tensor(47.6157)
# ▁? tensor(47.6027)
# ▁„ tensor(47.5630)
# ▁sich tensor(47.5292)
# ▁w tensor(47.5136)
# ▁mehr tensor(47.5082)
# ▁aus tensor(47.4889)
# ▁dieses tensor(47.4888)
# ▁zum tensor(47.4803)
# ▁selbst tensor(47.4767)
# ▁Ihr tensor(47.4561)
# ▁Du tensor(47.4388)
# ▁ni tensor(47.4382)
# ▁erst tensor(47.4231)
# ▁ihren tensor(47.4143)

# %% [markdown]
# Predict the most probable word that is not part of the new embeddings:

# %%
predicted_token_ids = torch.argmax(predictions[0, masked_index])
vocab_size = len(tokenizer)
# Find the highest predicted token with an ID lower than 28997
for i in range(vocab_size):
    if predicted_token_ids < 28996:  # if no [PAD]: <= 28996
        break
    predicted_token_ids = torch.argsort(predictions[0, masked_index], descending=True)[i]

# Convert the predicted token ID back to a token
predicted_token = tokenizer.convert_ids_to_tokens([predicted_token_ids])[0]

print(predicted_token)
# Out:
# ▁sie

# %% [markdown]
# Predict the top 5 words that are not part of the new embeddings:

# %%
# Get the predicted token IDs and their probabilities
predicted_token_probs = predictions[0, masked_index]
vocab_size = len(tokenizer)
# Create a list to store the top 5 predictions and their probabilities
top_5_predictions = []

# Find the top 5 predicted tokens with IDs lower than 28997
for i in range(vocab_size):
    if len(top_5_predictions) >= 5 or i >= vocab_size:
        break
    token_id = torch.argsort(predicted_token_probs, descending=True)[i].item()
    if token_id < 28996:  # if no [PAD]: <= 28996
        predicted_token = tokenizer.convert_ids_to_tokens([token_id])[0]
        top_5_predictions.append((predicted_token, predicted_token_probs[token_id].item()))

# Print the top 5 predictions and their probabilities
for token, prob in top_5_predictions:
    print(token, prob)
# Out:
# ▁sie 52.33668899536133
# ▁das 51.55738830566406
# ▁es 51.08205795288086
# ▁auch 50.88592529296875
# ▁die 50.74215316772461

# %%
# TODO Generate instead of predicting!

# %%
test_text = "de_DE <s> Geschweige10 denn <mask>.</s>"

outputs = tokenizer(test_text, return_tensors="pt")
outputs = model.generate(outputs["input_ids"], max_length=100, num_return_sequences=5,
                         num_beams=20, output_scores=True, return_dict_in_generate=True)
output_strings = tokenizer.batch_decode(outputs.sequences, skip_special_tokens=True)
output_probs = torch.exp(outputs.sequences_scores)

print([f'output: {output}, score: {score}'
       for output, score in zip(output_strings, output_probs)])
# Out:
# ['output: Was ist denn das?.., score: 0.4156593382358551', 'output: Was ist denn das..., score: 0.39563310146331787', 'output: Was ist denn nun..., score: 0.3922627568244934', 'output: Was ist denn eigentlich.., score: 0.38697561621665955', 'output: ist es denn nicht..., score: 0.3854128420352936']
